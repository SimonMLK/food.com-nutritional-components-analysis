# %%
from google.colab import drive
drive.mount('/content/drive')

# now can import drive files as usual files with the path like
# /content/drive/My Drive/location_of_the_file
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import nltk
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag
from nltk.corpus import stopwords
from nltk import everygrams
from collections import Counter
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')

STOP_WORDS = [x.lower() for x in set(stopwords.words('english'))]
PUNCTUATION_TO_REMOVE = [",", ".", ";", "!", '"', "?", '“', '”', "‘", '’',
                         "[", "]", "{", "}",')','(', '...', "n't", "'s","''", "-"
                         ,':', '``', 'br', 'gt']
NO_MEANING_TO_REMOVE = ["lt", "quot", "next", "thanks", "thank", "also", "use", "used", "'ve", "add", "added", "br/", "039"]
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
import pandas as pd

DRIVE_INITIAL_PATH = r"/content/drive/My Drive/Data Mining"

def adapt_path_to_drive(original_path):
  return "/".join([DRIVE_INITIAL_PATH, original_path])



OUR_PP_RECIPES_PATH = r"data/our_pp_recipes.csv"
OUR_PP_INTERACTIONS_PATH = r"data/our_pp_interactions.csv"

OUR_PP_RECIPES_PATH = adapt_path_to_drive(OUR_PP_RECIPES_PATH)
OUR_PP_INTERACTIONS_PATH = adapt_path_to_drive(OUR_PP_INTERACTIONS_PATH)


PP_INTERACTIONS_DF = pd.read_csv(OUR_PP_INTERACTIONS_PATH)
PP_RECIPES_DF = pd.read_csv(OUR_PP_RECIPES_PATH)

# %%
date_ranges_start_points = ['2000-01-01','2004-01-01', '2008-01-01', '2012-01-01', '2016-01-01']
end_point = '2020-01-01'

filtered_interactions_sorted = PP_INTERACTIONS_DF.sort_values("date")
array_of_divides = []
for i in range(len(date_ranges_start_points)):
  if i == len(date_ranges_start_points) - 1:
    cur_df = filtered_interactions_sorted.loc[(filtered_interactions_sorted["date"] >= date_ranges_start_points[i]) & (filtered_interactions_sorted["date"] < end_point)]
  else:
    cur_df = filtered_interactions_sorted.loc[(filtered_interactions_sorted["date"] >= date_ranges_start_points[i]) & (filtered_interactions_sorted["date"] < date_ranges_start_points[i+1])]
  cur_df = cur_df.fillna("")
  array_of_divides.append(cur_df)

array_of_divides_of_sugar = [df[df['review'].str.lower().str.contains("sugar")] for df in array_of_divides] # array of dataframe each dataframe is for a certain time range and contains only reviews which contains the word sugar

# %% [markdown]
# # Strings fitting

# %%
def get_review_divides(sugar_reviews_df):
  """
  concatenating strings from review param into a one long string
  """
  long_str = ''
  for string in sugar_reviews_df["review"]:
    long_str += ' ' + string
  return long_str

sugar_text1, sugar_text2, sugar_text3, sugar_text4, sugar_text5 = [get_review_divides(x) for x in array_of_divides_of_sugar] 
sugar_text_lst = [sugar_text1, sugar_text2, sugar_text3, sugar_text4, sugar_text5]

# %% [markdown]
# # Tokenizing & String cleaning

# %%
def tokenizer(data):
  not_in_list = STOP_WORDS + PUNCTUATION_TO_REMOVE + NO_MEANING_TO_REMOVE
  tokens = word_tokenize(data)
  tokens = [x.lower() for x in tokens if (x not in not_in_list) and (len(x) > 1)]
  print("done tokenizing")
  return tokens

sugar_tokens1, sugar_tokens2, sugar_tokens3, sugar_tokens4, sugar_tokens5 = [tokenizer(x) for x in sugar_text_lst]
# Out:
# done tokenizing
# done tokenizing
# done tokenizing
# done tokenizing
# done tokenizing

# %% [markdown]
# # Sugar trigrams printing

# %%
def sugar_val_filter(tokenized_trigrams):
  ret_lst = []
  for tup in tokenized_trigrams:
    if 'sugar' in tup:
      ret_lst.append(tup)
    else:
        continue
  return ret_lst

# %%
trigram_tokens1 = nltk.everygrams(sugar_tokens1, 4,4) 
trigram_tokens1=sugar_val_filter(trigram_tokens1)
print(Counter(trigram_tokens1).most_common()[:50])
# Out:
# [(('brown', 'sugar', 'instead', 'white'), 10), (('1/2', 'cup', 'brown', 'sugar'), 9), (('1/4', 'cup', 'brown', 'sugar'), 9), (('cut', 'back', 'brown', 'sugar'), 7), (('brown', 'sugar', '1/2', 'cup'), 6), (('brown', 'sugar', '1/4', 'cup'), 5), (('sweet', 'low', 'brown', 'sugar'), 4), (('sugar', 'instead', 'granulated', 'sugar'), 4), (('sugar', 'thanks', 'great', 'recipe'), 4), (('brown', 'sugar', 'instead', 'granulated'), 4), (('sugar', 'twin', 'brown', 'sugar'), 4), (('try', 'less', 'sugar', 'time'), 4), (('sugar', 'instead', 'white', 'sugar'), 4), (('next', 'time', 'cut', 'sugar'), 4), (('splenda', 'instead', 'brown', 'sugar'), 4), (('brown', 'sugar', 'it', 'little'), 3), (('sugar', 'it', 'little', 'sweet'), 3), (('time', 'cut', 'back', 'sugar'), 3), (('cut', 'back', 'sugar', 'bit'), 3), (('cut', 'brown', 'sugar', 'half'), 3), (('light', 'brown', 'sugar', 'instead'), 3), (('brown', 'sugar', 'instead', 'dark'), 3), (('powdered', 'sugar', 'orange', 'juice'), 3), (('lemon', 'juice', 'powdered', 'sugar'), 3), (('substituted', 'brown', 'sugar', 'white'), 3), (('brown', 'sugar', 'worcestershire', 'sauce'), 3), (('sugar', 'free', 'pudding', 'mix'), 3), (('recipe', 'splenda', 'instead', 'sugar'), 3), (('brown', 'sugar', 'personal', 'taste'), 3), (('cup', 'packed', 'brown', 'sugar'), 3), (('sprinkled', 'powdered', 'sugar', 'thanks'), 3), (('sugar', 'free', 'maple', 'syrup'), 3), (('3/4', 'cup', 'white', 'sugar'), 3), (('maple', 'syrup', 'brown', 'sugar'), 3), (('powdered', 'sugar', 'lemon', 'juice'), 3), (('1/2', 'cup', 'white', 'sugar'), 3), (('half', 'brown', 'sugar', 'half'), 3), (('3/4', 'cup', 'brown', 'sugar'), 3), (('little', 'cinnamon', 'sugar', 'top'), 2), (('sprinkle', 'cinnamon', 'sugar', 'baking'), 2), (('sugar', 'fresh', 'lemon', 'juice'), 2), (('back', 'brown', 'sugar', 'time'), 2), (('sugar', 'sprinkled', 'top', 'made'), 2), (('cut', 'back', 'sugar', 'time'), 2), (('sugar', 'still', 'turned', 'great'), 2), (('cup', 'sugar', 'it', 'good'), 2), (('cut', 'sugar', '1/2', 'tsp'), 2), (('sugar', '2/3', 'cup', 'cup'), 2), (('sprinkled', 'powdered', 'sugar', 'top'), 2), (('ca', 'tell', 'sugar', 'free'), 2)]

# %% [markdown]
# ## Trigrams prints

# %%
trigram_tokens1 = nltk.trigrams(sugar_tokens1) 
trigram_tokens1=sugar_val_filter(trigram_tokens1)
print(Counter(trigram_tokens1).most_common()[:50])

trigram_tokens1 = nltk.trigrams(sugar_tokens2) 
trigram_tokens1=sugar_val_filter(trigram_tokens1)
print(Counter(trigram_tokens1).most_common()[:50])


trigram_tokens1 = nltk.trigrams(sugar_tokens3) 
trigram_tokens1=sugar_val_filter(trigram_tokens1)
print(Counter(trigram_tokens1).most_common()[:50])


trigram_tokens1 = nltk.trigrams(sugar_tokens4) 
trigram_tokens1=sugar_val_filter(trigram_tokens1)
print(Counter(trigram_tokens1).most_common()[:50])


trigram_tokens1 = nltk.trigrams(sugar_tokens5) 
trigram_tokens1=sugar_val_filter(trigram_tokens1)
print(Counter(trigram_tokens1).most_common()[:50])
# Out:
# [(('cut', 'back', 'sugar'), 30), (('cup', 'brown', 'sugar'), 29), (('brown', 'sugar', 'instead'), 27), (('splenda', 'instead', 'sugar'), 27), (('1/2', 'cup', 'sugar'), 26), (('1/4', 'cup', 'sugar'), 22), (('dark', 'brown', 'sugar'), 18), (('the', 'brown', 'sugar'), 17), (('sugar', '1/2', 'cup'), 15), (('light', 'brown', 'sugar'), 15), (('little', 'less', 'sugar'), 14), (('little', 'brown', 'sugar'), 14), (('dusted', 'powdered', 'sugar'), 14), (('cut', 'sugar', 'half'), 14), (('sugar', 'snap', 'peas'), 14), (('sugar', '1/4', 'cup'), 13), (('sprinkled', 'powdered', 'sugar'), 12), (('amount', 'brown', 'sugar'), 12), (('butter', 'brown', 'sugar'), 12), (('brown', 'sugar', '1/2'), 11), (('brown', 'sugar', 'white'), 11), (('substituted', 'splenda', 'sugar'), 11), (('cup', 'white', 'sugar'), 11), (('cut', 'brown', 'sugar'), 10), (('sugar', 'free', 'jello'), 10), (('sugar', 'instead', 'white'), 10), (('brown', 'sugar', 'the'), 9), (('1/2', 'cups', 'sugar'), 9), (('little', 'bit', 'sugar'), 9), (('sugar', '3/4', 'cup'), 9), (('3/4', 'cup', 'sugar'), 9), (('brown', 'sugar', 'substitute'), 9), (('instead', 'brown', 'sugar'), 9), (('sugar', 'brown', 'sugar'), 9), (('brown', 'sugar', 'cinnamon'), 9), (('back', 'brown', 'sugar'), 8), (('brown', 'sugar', 'time'), 8), (('brown', 'sugar', 'it'), 8), (('cup', 'powdered', 'sugar'), 8), (('tbsp', 'brown', 'sugar'), 8), (('powdered', 'sugar', 'top'), 8), (('garlic', 'brown', 'sugar'), 8), (('brown', 'sugar', 'half'), 8), (('ketchup', 'brown', 'sugar'), 8), (('powdered', 'sugar', 'instead'), 8), (('powdered', 'sugar', 'glaze'), 8), (('less', 'sugar', 'time'), 8), (('brown', 'sugar', 'made'), 8), (('cinnamon', 'sugar', 'top'), 7), (('sprinkled', 'cinnamon', 'sugar'), 7)]
# [(('splenda', 'brown', 'sugar'), 376), (('splenda', 'instead', 'sugar'), 355), (('cup', 'brown', 'sugar'), 296), (('cut', 'back', 'sugar'), 255), (('sugar', '1/2', 'cup'), 218), (('1/2', 'cup', 'sugar'), 215), (('brown', 'sugar', 'instead'), 192), (('sugar', '1/4', 'cup'), 158), (('1/4', 'cup', 'sugar'), 152), (('brown', 'sugar', 'blend'), 142), (('splenda', 'place', 'sugar'), 123), (('dark', 'brown', 'sugar'), 117), (('light', 'brown', 'sugar'), 111), (('little', 'less', 'sugar'), 109), (('brown', 'sugar', '1/2'), 107), (('little', 'brown', 'sugar'), 103), (('brown', 'sugar', 'cinnamon'), 102), (('sugar', 'snap', 'peas'), 95), (('sugar', '3/4', 'cup'), 93), (('3/4', 'cup', 'sugar'), 93), (('butter', 'brown', 'sugar'), 92), (('the', 'brown', 'sugar'), 87), (('brown', 'sugar', 'splenda'), 84), (('cut', 'brown', 'sugar'), 83), (('cut', 'sugar', 'half'), 82), (('sugar', 'brown', 'sugar'), 81), (('instead', 'brown', 'sugar'), 79), (('sugar', 'instead', 'white'), 78), (('sugar', 'free', 'pudding'), 71), (('cup', 'powdered', 'sugar'), 69), (('half', 'brown', 'sugar'), 67), (('brown', 'sugar', 'top'), 67), (('brown', 'sugar', 'half'), 67), (('cup', 'white', 'sugar'), 66), (('dusted', 'powdered', 'sugar'), 65), (('powdered', 'sugar', 'top'), 64), (('sprinkled', 'powdered', 'sugar'), 62), (('tbsp', 'brown', 'sugar'), 61), (('sugar', '1/3', 'cup'), 60), (('sugar', 'free', 'jello'), 60), (('1/3', 'cup', 'sugar'), 59), (('amount', 'brown', 'sugar'), 59), (('sprinkled', 'cinnamon', 'sugar'), 59), (('substituted', 'splenda', 'sugar'), 57), (('brown', 'sugar', 'topping'), 57), (('honey', 'instead', 'sugar'), 55), (('bit', 'brown', 'sugar'), 55), (('brown', 'sugar', '1/4'), 55), (('cups', 'powdered', 'sugar'), 54), (('little', 'bit', 'sugar'), 53)]
# [(('cup', 'brown', 'sugar'), 563), (('splenda', 'brown', 'sugar'), 558), (('sugar', '1/2', 'cup'), 425), (('splenda', 'instead', 'sugar'), 395), (('1/2', 'cup', 'sugar'), 376), (('cut', 'back', 'sugar'), 352), (('sugar', '1/4', 'cup'), 341), (('dark', 'brown', 'sugar'), 319), (('brown', 'sugar', 'instead'), 306), (('1/4', 'cup', 'sugar'), 247), (('brown', 'sugar', 'blend'), 216), (('brown', 'sugar', '1/2'), 197), (('splenda', 'place', 'sugar'), 191), (('light', 'brown', 'sugar'), 181), (('little', 'less', 'sugar'), 177), (('cut', 'sugar', 'half'), 172), (('sugar', 'snap', 'peas'), 165), (('little', 'brown', 'sugar'), 163), (('3/4', 'cup', 'sugar'), 152), (('sugar', '3/4', 'cup'), 151), (('brown', 'sugar', 'cinnamon'), 140), (('half', 'brown', 'sugar'), 140), (('cup', 'white', 'sugar'), 139), (('sugar', 'instead', 'white'), 137), (('bit', 'brown', 'sugar'), 136), (('brown', 'sugar', 'splenda'), 127), (('sugar', 'brown', 'sugar'), 126), (('brown', 'sugar', 'half'), 125), (('cut', 'brown', 'sugar'), 125), (('honey', 'instead', 'sugar'), 122), (('butter', 'brown', 'sugar'), 120), (('brown', 'sugar', '1/4'), 115), (('the', 'brown', 'sugar'), 115), (('instead', 'brown', 'sugar'), 112), (('1/3', 'cup', 'sugar'), 111), (('cup', 'powdered', 'sugar'), 110), (('cups', 'powdered', 'sugar'), 108), (('cut', 'sugar', 'back'), 108), (('sugar', '1/3', 'cup'), 101), (('tbsp', 'brown', 'sugar'), 99), (('cut', 'sugar', '1/2'), 94), (('powdered', 'sugar', 'top'), 92), (('brown', 'sugar', 'made'), 92), (('amount', 'brown', 'sugar'), 91), (('sugar', 'cookie', 'recipe'), 91), (('tablespoon', 'brown', 'sugar'), 89), (('brown', 'sugar', 'butter'), 86), (('brown', 'sugar', 'white'), 86), (('tablespoons', 'brown', 'sugar'), 86), (('1/2', 'brown', 'sugar'), 83)]
# [(('cup', 'brown', 'sugar'), 198), (('sugar', '1/2', 'cup'), 144), (('brown', 'sugar', 'instead'), 133), (('cut', 'back', 'sugar'), 127), (('sugar', '1/4', 'cup'), 123), (('1/2', 'cup', 'sugar'), 122), (('dark', 'brown', 'sugar'), 106), (('1/4', 'cup', 'sugar'), 85), (('cut', 'sugar', 'half'), 80), (('splenda', 'brown', 'sugar'), 79), (('light', 'brown', 'sugar'), 78), (('splenda', 'instead', 'sugar'), 68), (('sugar', 'instead', 'white'), 64), (('little', 'less', 'sugar'), 63), (('sugar', 'brown', 'sugar'), 62), (('cup', 'white', 'sugar'), 60), (('sugar', '3/4', 'cup'), 57), (('little', 'brown', 'sugar'), 57), (('brown', 'sugar', '1/2'), 56), (('sugar', 'snap', 'peas'), 52), (('3/4', 'cup', 'sugar'), 52), (('brown', 'sugar', 'cinnamon'), 48), (('brown', 'sugar', 'white'), 48), (('butter', 'brown', 'sugar'), 47), (('brown', 'sugar', 'half'), 47), (('honey', 'instead', 'sugar'), 47), (('cups', 'powdered', 'sugar'), 43), (('cut', 'sugar', '1/2'), 42), (('half', 'brown', 'sugar'), 39), (('sugar', 'cookie', 'recipe'), 38), (('instead', 'brown', 'sugar'), 37), (('brown', 'sugar', '1/4'), 37), (('brown', 'sugar', 'made'), 36), (('tablespoon', 'brown', 'sugar'), 36), (('1/3', 'cup', 'sugar'), 36), (('sugar', '1/3', 'cup'), 36), (('brown', 'sugar', 'blend'), 35), (('cup', 'powdered', 'sugar'), 35), (('less', 'brown', 'sugar'), 35), (('brown', 'sugar', 'the'), 35), (('bit', 'brown', 'sugar'), 35), (('cut', 'sugar', 'back'), 33), (('organic', 'cane', 'sugar'), 33), (('tablespoons', 'brown', 'sugar'), 32), (('the', 'brown', 'sugar'), 32), (('tbsp', 'brown', 'sugar'), 32), (('instead', 'white', 'sugar'), 31), (('tbs', 'brown', 'sugar'), 29), (('brown', 'sugar', 'little'), 29), (('sugar', 'thanks', 'sharing'), 29)]
# [(('cup', 'brown', 'sugar'), 122), (('sugar', '1/2', 'cup'), 76), (('1/2', 'cup', 'sugar'), 71), (('brown', 'sugar', 'instead'), 66), (('dark', 'brown', 'sugar'), 59), (('light', 'brown', 'sugar'), 47), (('sugar', '1/4', 'cup'), 46), (('1/4', 'cup', 'sugar'), 46), (('cup', 'white', 'sugar'), 45), (('cut', 'sugar', 'half'), 44), (('cut', 'back', 'sugar'), 40), (('sugar', 'brown', 'sugar'), 37), (('sugar', 'instead', 'white'), 36), (('sugar', '3/4', 'cup'), 30), (('brown', 'sugar', 'cinnamon'), 29), (('brown', 'sugar', 'half'), 29), (('3/4', 'cup', 'sugar'), 28), (('1/3', 'cup', 'sugar'), 28), (('brown', 'sugar', '1/2'), 27), (('instead', 'brown', 'sugar'), 27), (('sugar', '1/3', 'cup'), 27), (('little', 'brown', 'sugar'), 26), (('sugar', 'half', 'cup'), 25), (('half', 'brown', 'sugar'), 25), (('instead', 'white', 'sugar'), 25), (('little', 'less', 'sugar'), 25), (('half', 'cup', 'sugar'), 24), (('sugar', 'cookie', 'recipe'), 24), (('brown', 'sugar', 'top'), 24), (('butter', 'brown', 'sugar'), 23), (('cups', 'powdered', 'sugar'), 21), (('sugar', 'top', 'baking'), 21), (('brown', 'sugar', '1/4'), 20), (('honey', 'instead', 'sugar'), 20), (('one', 'cup', 'sugar'), 19), (('cut', 'brown', 'sugar'), 19), (('white', 'sugar', 'brown'), 19), (('cup', 'powdered', 'sugar'), 18), (('coconut', 'sugar', 'instead'), 18), (('tbsp', 'brown', 'sugar'), 17), (('sugar', '1/2', 'cups'), 16), (('splenda', 'brown', 'sugar'), 16), (('splenda', 'instead', 'sugar'), 16), (('1/2', 'cups', 'sugar'), 16), (('half', 'white', 'sugar'), 16), (('cinnamon', 'sugar', 'top'), 16), (('cut', 'sugar', 'back'), 16), (('brown', 'sugar', 'white'), 16), (('cinnamon', 'brown', 'sugar'), 15), (('way', 'much', 'sugar'), 15)]

# %% [markdown]
# ## Fourgrams Prints

# %%
trigram_tokens1 = nltk.fourgrams(sugar_tokens1) 
trigram_tokens1=sugar_val_filter(trigram_tokens1)
print(Counter(trigram_tokens1).most_common()[:50])

trigram_tokens1 = nltk.fourgrams(sugar_tokens2) 
trigram_tokens1=sugar_val_filter(trigram_tokens1)
print(Counter(trigram_tokens1).most_common()[:50])


trigram_tokens1 = nltk.fourgrams(sugar_tokens3) 
trigram_tokens1=sugar_val_filter(trigram_tokens1)
print(Counter(trigram_tokens1).most_common()[:50])


trigram_tokens1 = nltk.fourgrams(sugar_tokens4) 
trigram_tokens1=sugar_val_filter(trigram_tokens1)
print(Counter(trigram_tokens1).most_common()[:50])


trigram_tokens1 = nltk.fourgrams(sugar_tokens5) 
trigram_tokens1=sugar_val_filter(trigram_tokens1)
print(Counter(trigram_tokens1).most_common()[:50])
